# %%
import pandas as pd
import missingno as mn
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime
matplotlib.rcParams['figure.figsize'] = [20, 10]
pd.set_option('display.max_columns', 500)

# %%
all_data = pd.read_csv('world_bank_data.csv', low_memory=False, thousands=',')

# %%
all_data.loc[(all_data['ibrdcommamt'] + all_data['idacommamt'] + all_data['grantamt']) != all_data['lendprojectcost']]
# Out:
#             id                    regionname  \
# 2      P160504         East Asia and Pacific
# 3      P157987                    South Asia
# 4      P158364                    South Asia
# 6      P165054       Europe and Central Asia
# 9      P165684                    South Asia
# 10     P156837       Europe and Central Asia
# 13     P164660   Latin America and Caribbean
# 17     P157575   Latin America and Caribbean
# 18     P160224  Middle East and North Africa
# 21     P165085   Latin America and Caribbean
# 23     P157054                    South Asia
# 24     P163452                        Africa
# 25     P157836                    South Asia
# 27     P165121       Europe and Central Asia
# 31     P160395                        Africa
# 32     P162908   Latin America and Caribbean
# 33     P165551   Latin America and Caribbean
# 34     P160641                        Africa
# 36     P164845                        Africa
# 37     P160408                    South Asia
# ...

# %%
all_data.loc[(all_data['ibrdcommamt'] + all_data['idacommamt']) != all_data['totalamt']]
# Out:
#             id                   regionname          countryname prodline  \
# 9754   P043923  Latin America and Caribbean      Grenada;Grenada       PE
# 10026  P038698  Latin America and Caribbean  St. Lucia;St. Lucia       PE
# 16750  P164646                        Other          World;World       PE
#
#                        lendinginstr lendinginstrtype envassesmentcategorycode  \
# 9754       Specific Investment Loan               IN                        C
# 10026      Specific Investment Loan               IN                        C
# 16750  Investment Project Financing               IN                        A
#
#       supplementprojectflg productlinetype projectstatusdisplay    status  \
# 9754                     N               L               Closed    Closed
# 10026                    N               L               Closed    Closed
# 16750                    N               L             Pipeline  Pipeline
#
# ...

# %%
rel_data = all_data[['id','regionname','countryname','boardapprovaldate','ibrdcommamt','idacommamt','grantamt']]

# %%
rel_data['boardapprovaldate'] = pd.to_datetime(rel_data['boardapprovaldate'])
# Out:
# /Users/vaidehidalmia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rel_data['year'] = rel_data['boardapprovaldate'].dt.year
# Out:
# /Users/vaidehidalmia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rel_data['totalamt'] = rel_data['ibrdcommamt'] + rel_data['idacommamt'] + rel_data['grantamt']
# Out:
# /Users/vaidehidalmia/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rel_data.head()
# Out:
#         id             regionname  \
# 0  P160543  East Asia and Pacific
# 1  P163515                 Africa
# 2  P160504  East Asia and Pacific
# 3  P157987             South Asia
# 4  P158364             South Asia
#
#                                          countryname boardapprovaldate  \
# 0  Socialist Republic of Vietnam;Socialist Republ...        2018-05-31
# 1              Republic of Uganda;Republic of Uganda        2018-05-15
# 2                Republic of Palau;Republic of Palau        2018-03-30
# 3  People's Republic of Bangladesh;People's Repub...        2018-03-29
# 4                                        Nepal;Nepal        2018-03-29
#
#    ibrdcommamt  idacommamt  grantamt    year   totalamt
# 0            0           0   3000000  2018.0    3000000
# 1            0   360000000         0  2018.0  360000000
# 2            0           0   1100000  2018.0    1100000
# 3            0    15000000         0  2018.0   15000000
# ...

# %%
rel_data.to_csv("rel_data.csv")

# %%
all_data['countryname'].unique()
# Out:
# array(['Socialist Republic of Vietnam;Socialist Republic of Vietnam',
#        'Republic of Uganda;Republic of Uganda',
#        'Republic of Palau;Republic of Palau',
#        "People's Republic of Bangladesh;People's Republic of Bangladesh",
#        'Nepal;Nepal', 'Republic of Angola;Republic of Angola',
#        'Republic of Uzbekistan;Republic of Uzbekistan',
#        'Republic of Serbia;Republic of Serbia',
#        'Republic of Colombia;Republic of Colombia',
#        'Islamic Republic of Pakistan;Islamic Republic of Pakistan',
#        'Kyrgyz Republic;Kyrgyz Republic',
#        'Republic of Peru;Republic of Peru',
#        'Republic of Mali;Republic of Mali',
#        'Republic of Guinea;Republic of Guinea',
#        'Islamic Republic of Mauritania;Islamic Republic of Mauritania',
#        'Republic of Panama;Republic of Panama',
#        'Lebanese Republic;Lebanese Republic',
#        'Republic of Nicaragua;Republic of Nicaragua',
# ...
